# %%
from faker import Faker
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('fake_dataset.csv')

# %%
data.head()
# Out:
#                     job                  company          ssn  \
# 0         Social worker               Walker Inc  310-63-0702
# 1          Asphaltbauer                 Boucsein  967-76-9482
# 2  Broadcast journalist   Nguyen, Ramos and Dean  235-28-8677
# 3     Librarian, public        Williams-Williams  214-93-2153
# 4               Pfleger  Oestrovsky Schacht GmbH  922-46-2976
#
#                                  residence  \
# 0         Unit 6109 Box 4735\nDPO AP 98523
# 1           Kaulallee 7\n26661 Wolmirstedt
# 2     9907 Mark Fort\nNew Nicole, CO 14642
# 3  47065 Smith Locks\nDavidville, KY 43807
# 4            Radischallee 8/8\n33870 Calau
#
#                                   current_location blood_group  \
# 0   (Decimal('-85.534605'), Decimal('152.984137'))          O+
# 1   (Decimal('31.485987'), Decimal('-175.643013'))          B-
# 2     (Decimal('3.932205'), Decimal('-38.257509'))          O-
# 3  (Decimal('33.3153335'), Decimal('-160.341802'))         AB-
# 4    (Decimal('-61.833307'), Decimal('84.607375'))         AB+
#
#                                              website     username  \
# 0  ['http://www.wyatt-anderson.com/', 'http://jim...    kenneth44
# 1  ['http://www.troest.org/', 'http://www.gehring...     gernot71
# 2                           ['http://mcdaniel.com/']  jennacooper
# 3  ['http://www.noble.net/', 'http://www.cervante...   julieallen
# 4        ['http://gude.org/', 'https://bender.net/']     flehmann
#
#                        name sex  ...                     mail   birthdate  \
# 0              Cassie Price   F  ...       paul72@hotmail.com  1962-04-27
# 1         Iris Tschentscher   F  ...    rittergordon@yahoo.de  1957-11-22
# 2            Tracy Anderson   F  ...  candacebutler@yahoo.com  1964-04-16
# 3          Kaitlin Williams   F  ...      jgonzalez@gmail.com  1996-06-04
# 4  Hansjoachim Knappe B.Sc.   M  ...          damian15@aol.de  1995-11-02
#
#   Android Version         Country                Company Email  \
# 0     Android 2.0       Hong Kong         isaacoconnor@fox.biz
# 1     Android 4.0          Jersey         kaylahall@knight.com
# 2   Android 8.1.0          सीरिया           fbarral@aleman.biz
# 3   Android 4.2.1     El Salvador  schleichantoinette@faust.de
# 4   Android 4.4.2  Norfolk Island           tillmann58@wulf.de
#
#                   UniqueID                          Catch Phrase  \
# 0     34153815819551915066      Cross-group maximized complexity
# 1  B2551902434698383161182  Concetto configurabile intermediaria
# 2       PAQG80977649775757        Proactive maximized middleware
# 3  M7603307334706892791590      Emulazione polarizzata reciproca
# 4       QDMI82127614226941    Distributed systematic parallelism
#
#        Credit Card Num       Best Color Fugitive
# 0  4947956431556505054  MediumVioletRed    False
# 1     2599199111799188        MistyRose    False
# 2     3529176192056996    DarkTurquoise     True
# 3       30256036859488       MediumBlue    False
# 4     5323942767652573             Snow     True
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   job               10000 non-null  object
#  1   company           10000 non-null  object
#  2   ssn               10000 non-null  object
#  3   residence         10000 non-null  object
#  4   current_location  10000 non-null  object
#  5   blood_group       10000 non-null  object
#  6   website           10000 non-null  object
#  7   username          10000 non-null  object
#  8   name              10000 non-null  object
#  9   sex               10000 non-null  object
#  10  address           10000 non-null  object
#  11  mail              10000 non-null  object
#  12  birthdate         10000 non-null  object
#  13  Android Version   10000 non-null  object
#  14  Country           10000 non-null  object
#  15  Company Email     10000 non-null  object
#  16  UniqueID          10000 non-null  object
#  17  Catch Phrase      10000 non-null  object
#  18  Credit Card Num   10000 non-null  int64
#  19  Best Color        10000 non-null  object
#  20  Fugitive          10000 non-null  bool
# dtypes: bool(1), int64(1), object(19)
# memory usage: 1.5+ MB

# %%
data.head()
# Out:
#                     job                  company          ssn  \
# 0         Social worker               Walker Inc  310-63-0702
# 1          Asphaltbauer                 Boucsein  967-76-9482
# 2  Broadcast journalist   Nguyen, Ramos and Dean  235-28-8677
# 3     Librarian, public        Williams-Williams  214-93-2153
# 4               Pfleger  Oestrovsky Schacht GmbH  922-46-2976
#
#                                  residence  \
# 0         Unit 6109 Box 4735\nDPO AP 98523
# 1           Kaulallee 7\n26661 Wolmirstedt
# 2     9907 Mark Fort\nNew Nicole, CO 14642
# 3  47065 Smith Locks\nDavidville, KY 43807
# 4            Radischallee 8/8\n33870 Calau
#
#                                   current_location blood_group  \
# 0   (Decimal('-85.534605'), Decimal('152.984137'))          O+
# 1   (Decimal('31.485987'), Decimal('-175.643013'))          B-
# 2     (Decimal('3.932205'), Decimal('-38.257509'))          O-
# 3  (Decimal('33.3153335'), Decimal('-160.341802'))         AB-
# 4    (Decimal('-61.833307'), Decimal('84.607375'))         AB+
#
#                                              website     username  \
# 0  ['http://www.wyatt-anderson.com/', 'http://jim...    kenneth44
# 1  ['http://www.troest.org/', 'http://www.gehring...     gernot71
# 2                           ['http://mcdaniel.com/']  jennacooper
# 3  ['http://www.noble.net/', 'http://www.cervante...   julieallen
# 4        ['http://gude.org/', 'https://bender.net/']     flehmann
#
#                        name sex  ...                     mail   birthdate  \
# 0              Cassie Price   F  ...       paul72@hotmail.com  1962-04-27
# 1         Iris Tschentscher   F  ...    rittergordon@yahoo.de  1957-11-22
# 2            Tracy Anderson   F  ...  candacebutler@yahoo.com  1964-04-16
# 3          Kaitlin Williams   F  ...      jgonzalez@gmail.com  1996-06-04
# 4  Hansjoachim Knappe B.Sc.   M  ...          damian15@aol.de  1995-11-02
#
#   Android Version         Country                Company Email  \
# 0     Android 2.0       Hong Kong         isaacoconnor@fox.biz
# 1     Android 4.0          Jersey         kaylahall@knight.com
# 2   Android 8.1.0          सीरिया           fbarral@aleman.biz
# 3   Android 4.2.1     El Salvador  schleichantoinette@faust.de
# 4   Android 4.4.2  Norfolk Island           tillmann58@wulf.de
#
#                   UniqueID                          Catch Phrase  \
# 0     34153815819551915066      Cross-group maximized complexity
# 1  B2551902434698383161182  Concetto configurabile intermediaria
# 2       PAQG80977649775757        Proactive maximized middleware
# 3  M7603307334706892791590      Emulazione polarizzata reciproca
# 4       QDMI82127614226941    Distributed systematic parallelism
#
#        Credit Card Num       Best Color Fugitive
# 0  4947956431556505054  MediumVioletRed    False
# 1     2599199111799188        MistyRose    False
# 2     3529176192056996    DarkTurquoise     True
# 3       30256036859488       MediumBlue    False
# 4     5323942767652573             Snow     True
#
# [5 rows x 21 columns]

# %%
data.blood_group.value_counts()
# Out:
# O+     1311
# A+     1272
# AB+    1260
# AB-    1245
# B-     1245
# B+     1242
# O-     1223
# A-     1202
# Name: blood_group, dtype: int64

# %%
sns.heatmap(data.corr(), cmap='viridis')
